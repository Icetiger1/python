# %% [markdown]
# <a href="https://colab.research.google.com/github/Icetiger1/python/blob/main/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D0%B5%2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

import pickle

# %% [markdown]
# #Загрузка данных

# %%
# !git clone https://github.com/Lasttrader/DA_repo
# Out:
# Cloning into 'DA_repo'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 63 (delta 1), reused 1 (delta 0), pack-reused 58
# Receiving objects: 100% (63/63), 31.42 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
path = '/content/DA_repo/titanic_train.csv'

# %%
data = pd.read_csv(path, index_col = 0)
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data = pd.read_excel()

# %% [markdown]
# #Обработка категориальных признаков

# %%
cat_cols = data.describe(include='object').columns.to_list()

# %%
cat_cols[1:]
# Out:
# ['Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
data_cat = data[cat_cols[1:]]
data_cat.head()
# Out:
#                 Sex            Ticket Cabin Embarked
# PassengerId
# 1              male         A/5 21171   NaN        S
# 2            female          PC 17599   C85        C
# 3            female  STON/O2. 3101282   NaN        S
# 4            female            113803  C123        S
# 5              male            373450   NaN        S

# %% [markdown]
# ##labelEncoder

# %%
le = LabelEncoder()
for col in list(data_cat.columns):
  data_cat[col + '_LE'] = le.fit_transform(data_cat[col])
  with open(f'{col}_LE.pkl', 'wb') as f:
    pickle.dump(le, f) #сохранение модели кодировщика в файл
data_cat.head()
# Out:
# <ipython-input-18-97ba62168484>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cat[col + '_LE'] = le.fit_transform(data_cat[col])
# <ipython-input-18-97ba62168484>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cat[col + '_LE'] = le.fit_transform(data_cat[col])
# <ipython-input-18-97ba62168484>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_cat_final = data_cat.drop(cat_cols[1:], axis =1)
data_cat_final.head()
# Out:
#              Sex_LE  Ticket_LE  Cabin_LE  Embarked_LE
# PassengerId
# 1                 1        523       147            2
# 2                 0        596        81            0
# 3                 0        669       147            2
# 4                 0         49        55            2
# 5                 1        472       147            2

# %%
data_cat_final.isna().sum()
# Out:
# Sex_LE         0
# Ticket_LE      0
# Cabin_LE       0
# Embarked_LE    0
# dtype: int64

# %% [markdown]
# #Числовые признаки

# %%
num_cols = data.describe().columns.to_list()
data_num = data[num_cols]
data_num.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500

# %% [markdown]
# #Нормализация

# %%
'''
1. открытие приложения
2. вводит категориальные признаки
3. вводить числовые признаки
4. категориальные призхнаки  в индексы (кодирование)
5. применить standardscaler на всё векторе
6. predict
7. result
'''

# %%
dataset = pd.concat([data_num, data_cat_final], axis =1)
dataset.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_LE  Ticket_LE  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500       1        523
# 2                   1       1  38.0      1      0  71.2833       0        596
# 3                   1       3  26.0      0      0   7.9250       0        669
# 4                   1       1  35.0      1      0  53.1000       0         49
# 5                   0       3  35.0      0      0   8.0500       1        472
#
#              Cabin_LE  Embarked_LE
# PassengerId
# 1                 147            2
# 2                  81            0
# 3                 147            2
# 4                  55            2
# 5                 147            2

# %% [markdown]
# ##StandardScaler

# %%
scaler = StandardScaler()
dataset_scaled = scaler.fit_transform(dataset.drop('Survived', axis =1))

# %%
with open('num_scaler.pkl', 'wb') as f:
  pickle.dump(scaler, f) #сохраняем скелер, для приложения

# %%
dataset_scaled_df = pd.DataFrame(data = dataset_scaled,
                                 columns = dataset.drop('Survived', axis =1).columns.to_list())
dataset_scaled_df.head()
# Out:
#      Pclass       Age     SibSp     Parch      Fare    Sex_LE  Ticket_LE  \
# 0  0.827377 -0.530377  0.432793 -0.473674 -0.502445  0.737695   0.918966
# 1 -1.566107  0.571831  0.432793 -0.473674  0.786845 -1.355574   1.282625
# 2  0.827377 -0.254825 -0.474545 -0.473674 -0.488854 -1.355574   1.646283
# 3 -1.566107  0.365167  0.432793 -0.473674  0.420730 -1.355574  -1.442322
# 4  0.827377  0.365167 -0.474545 -0.473674 -0.486337  0.737695   0.664904
#
#    Cabin_LE  Embarked_LE
# 0  0.451502     0.581114
# 1 -1.381627    -1.938460
# 2  0.451502     0.581114
# 3 -2.103768     0.581114
# 4  0.451502     0.581114

# %%
dataset_scaled_df['Age'] = dataset_scaled_df['Age'].fillna(dataset_scaled_df['Age'].mean())

# %%
dataset_scaled_df.isna().sum()
# Out:
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Sex_LE         0
# Ticket_LE      0
# Cabin_LE       0
# Embarked_LE    0
# dtype: int64

# %% [markdown]
# #X,y train_test_split

# %%
y = np.array(data['Survived'])
X = np.array(dataset_scaled_df)

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = 0.2,
                                                    shuffle = True,
                                                    random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (712, 9)
# (179, 9)
# (712,)
# (179,)

# %% [markdown]
# #ML

# %%
kNN = KNeighborsClassifier(n_neighbors=5)
kNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
kNN.predict(X_test[:5])
# Out:
# array([0, 0, 0, 1, 0])

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %% [markdown]
# ##Сохраняем модель ML

# %%
with open('kNN.pkl', 'wb') as f:
  pickle.dump(kNN, f) #сохраняем скелер, для приложения

# %%
# !git clone https://github.com/Lasttrader/04112023prod.git
# Out:
# Cloning into '04112023prod'...
# ...

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.6
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.1.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.13.1
# backcall                         0.2.0
# ...
